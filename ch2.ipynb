# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.plot(np.random.randn(50).cumsum())

# %%
a = [1,2,3,4,5]
b = a
c = list(a)
a is b
#判断引用是否指向同个对象
# Out:
# True

# %%
s = 'this\has'
s
# Out:
# 'this\\has'

# %%
temp = '{0:.1f} {1:s} '
temp.format(4.566,'python')
temp.format?

# %%
from datetime import datetime, date, time
dt = datetime(2019,2,27,21,21,21)
# dt.day
# date = dt.date()
print(dt)
dt1 = dt.strftime('%Y/%m/%d %H:%M:%S')
print(dt1)
# Out:
# 2019-02-27 21:21:21
# 2019/02/27 21:21:21
